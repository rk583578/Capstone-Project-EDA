# %% [markdown]
# # **Project Name**    - Amazon Prime Video Content Analysis & Insights

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# In the rapidly evolving OTT streaming industry, platforms such as Amazon Prime Video face intense competition to retain users and attract new subscribers. With thousands of movies and TV shows available, understanding content performance, audience preferences, and production trends through data analysis is critical for making informed business decisions.
#
# This capstone project focuses on performing Exploratory Data Analysis (EDA) on Amazon Prime Video’s U.S. content catalog. The dataset consists of two CSV files: titles data containing metadata for shows and movies, and credits data containing information about actors and directors. After merging both datasets, the final dataset contains over 124,000 records, representing content details along with cast and crew participation.
#
# The primary objective of this analysis is to identify meaningful patterns related to content type distribution, genre dominance, release trends, ratings, popularity metrics, and talent involvement. The project seeks to answer important business questions such as whether movies dominate over TV shows, which genres are most popular, how content production has evolved over time, and how ratings and popularity influence audience engagement.
#
# A structured analytical approach following the UBM (Univariate, Bivariate, and Multivariate) framework was applied. Univariate analysis was used to understand individual variables such as content type, genres, age certification, runtime, and rating distributions. Bivariate analysis explored relationships between two variables, such as IMDb score versus runtime, ratings versus popularity, and genre versus content performance. Multivariate analysis further examined interactions among multiple variables including genre, content type, ratings, and production regions.
#
# Data preprocessing and wrangling steps were performed to handle missing values, detect duplicate records, and ensure consistency across variables. Visualization libraries such as Matplotlib and Seaborn were used to create more than 20 logical and meaningful charts. Each visualization was accompanied by clear explanations, insights, and business impact assessments.
#
# The insights derived from this analysis provide actionable recommendations for stakeholders including content strategists, marketing teams, and investors. The findings highlight growth opportunities, such as expanding high-performing genres and improving TV show investments, as well as potential risks, such as limited family-friendly content. Overall, this project demonstrates how data-driven exploratory analysis can support strategic decision-making and sustainable growth in the streaming industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# To analyze Amazon Prime Video’s content catalog using exploratory data analysis techniques in order to identify trends, patterns, and insights related to content type, genres, ratings, popularity, and production dynamics, thereby supporting data-driven business decisions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# The business objective of this project is to help Amazon Prime Video understand audience preferences, optimize content strategy, identify high-performing genres and formats, and recognize potential gaps or risks in the content library that could impact user engagement and subscription growth.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# Ignore all warning

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
credits_df=pd.read_csv('/content/credits.csv')
titles_df=pd.read_csv('/content/titles.csv')


# Merge Data using left join

merged_df=pd.merge(credits_df,titles_df,how='left', on='id')
print(credits_df.shape)
print(titles_df.shape)
print(merged_df.shape)
# Out:
# (124235, 5)
# (9871, 15)
# (124347, 19)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# Print first 5 rows
merged_df.head()
# Out:
#    person_id       id           name      character   role              title  \
# 0      59401  ts20945     Joe Besser            Joe  ACTOR  The Three Stooges
# 1      31460  ts20945     Moe Howard            Moe  ACTOR  The Three Stooges
# 2      31461  ts20945     Larry Fine          Larry  ACTOR  The Three Stooges
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR        The General
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR        The General
#
#     type                                        description  release_year  \
# 0   SHOW  The Three Stooges were an American vaudeville ...          1934
# 1   SHOW  The Three Stooges were an American vaudeville ...          1934
# 2   SHOW  The Three Stooges were an American vaudeville ...          1934
# 3  MOVIE  During America’s Civil War, Union spies steal ...          1926
# 4  MOVIE  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# ...

# %%
# Print last 5 rows
merged_df.tail()
# Out:
#         person_id         id           name      character      role  \
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
#            title   type                                        description  \
# 124342  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124343  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124344  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124345  Baikunth  MOVIE  This story is about prevalent caste problem, e...
# 124346  Baikunth  MOVIE  This story is about prevalent caste problem, e...
#
#         release_year age_certification  runtime               genres  \
# ...

# %%
merged_df.head()
# Out:
#    person_id       id           name      character   role              title  \
# 0      59401  ts20945     Joe Besser            Joe  ACTOR  The Three Stooges
# 1      31460  ts20945     Moe Howard            Moe  ACTOR  The Three Stooges
# 2      31461  ts20945     Larry Fine          Larry  ACTOR  The Three Stooges
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR        The General
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR        The General
#
#     type                                        description  release_year  \
# 0   SHOW  The Three Stooges were an American vaudeville ...          1934
# 1   SHOW  The Three Stooges were an American vaudeville ...          1934
# 2   SHOW  The Three Stooges were an American vaudeville ...          1934
# 3  MOVIE  During America’s Civil War, Union spies steal ...          1926
# 4  MOVIE  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'Total Rows:-{merged_df.shape[0]}')
print(f'Total Columns:-{merged_df.shape[1]}')
# Out:
# Total Rows:-124347
# Total Columns:-19

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124347 non-null  int64
#  1   id                    124347 non-null  object
#  2   name                  124347 non-null  object
#  3   character             108040 non-null  object
#  4   role                  124347 non-null  object
#  5   title                 124347 non-null  object
#  6   type                  124347 non-null  object
#  7   description           124256 non-null  object
#  8   release_year          124347 non-null  int64
#  9   age_certification     56707 non-null   object
#  10  runtime               124347 non-null  int64
#  11  genres                124347 non-null  object
#  12  production_countries  124347 non-null  object
#  13  seasons               8153 non-null    float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(merged_df.duplicated().sum())
# Out:
# 168

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values=merged_df.isnull().sum()
missing_values=missing_values[missing_values>0]

# Visualizing the missing values
plt.figure(figsize=(12,6))
sns.barplot(x=missing_values.index, y=missing_values.values)
plt.xticks(rotation=30)
plt.xlabel('Columns')
plt.ylabel('Missing values Count')
plt.title('Missing values in merged dataset')
plt.show()
missing_values
# Out:
# character             16307
# description              91
# age_certification     67640
# seasons              116194
# imdb_id                5303
# imdb_score             6051
# imdb_votes             6075
# tmdb_popularity          15
# tmdb_score            10265
# dtype: int64

# %%
merged_df.dtypes
# Out:
# person_id                 int64
# id                       object
# name                     object
# character                object
# role                     object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
# Print all numerical columns
merged_df.select_dtypes(include=['int64','float64'])
# Out:
#         person_id  release_year  runtime  seasons  imdb_score  imdb_votes  \
# 0           59401          1934       19     26.0         8.6      1092.0
# 1           31460          1934       19     26.0         8.6      1092.0
# 2           31461          1934       19     26.0         8.6      1092.0
# 3           21174          1926       78      NaN         8.2     89766.0
# 4           28713          1926       78      NaN         8.2     89766.0
# ...           ...           ...      ...      ...         ...         ...
# 124342    1938589          2021       72      NaN         8.4        49.0
# 124343    1938565          2021       72      NaN         8.4        49.0
# 124344     728899          2021       72      NaN         8.4        49.0
# 124345    1938620          2021       72      NaN         8.4        49.0
# 124346    1938620          2021       72      NaN         8.4        49.0
#
#         tmdb_popularity  tmdb_score
# 0                15.424         7.6
# ...

# %%
# Print all categorical columns
merged_df.select_dtypes(include=['object'])
# Out:
#                id           name      character      role              title  \
# 0         ts20945     Joe Besser            Joe     ACTOR  The Three Stooges
# 1         ts20945     Moe Howard            Moe     ACTOR  The Three Stooges
# 2         ts20945     Larry Fine          Larry     ACTOR  The Three Stooges
# 3         tm19248  Buster Keaton    Johnny Gray     ACTOR        The General
# 4         tm19248    Marion Mack  Annabelle Lee     ACTOR        The General
# ...           ...            ...            ...       ...                ...
# 124342  tm1054116  Sangam Shukla         Madhav     ACTOR           Baikunth
# 124343  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR           Baikunth
# 124344  tm1054116  Vanya Wellens        Budhiya     ACTOR           Baikunth
# 124345  tm1054116   Vishwa Bhanu          Gissu     ACTOR           Baikunth
# 124346  tm1054116   Vishwa Bhanu            NaN  DIRECTOR           Baikunth
#
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# After merging the credits and titles dataset , here is what we know so far:
#
#   1. Dataset Structure
# AftTotal Rows: 124347 (After joining since we did left join)
# Total columns:19 (After joining)
#
#   2.   Key Columns
#
# Movie/Show Information: id, title ,type, description,release_year,genres, runtime
#
# Cast & Crew Details: name, character, role(Actor, directior),
#
# Rating and other: imdb_score, imdb_votes, tmdb_score, tmdb_votes, tmdb_popularity
#
#
#   3. Data issue duplicated and null value
#     Total Duplicated rows:168
#     Missing value: Several columns have missing value , including: Character (16307 missing), description(91 missing), age_certification (67640 missing), seasons (116194 missing value), imdb_id (5303 missing), imdb_score (6051 missing), imdb_votes (6075 missing), tmdb_popularity (15 missing) , tmdb_score (10265 missing)

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
merged_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
# Dataset Describe
merged_df.describe()
# Out:
#           person_id   release_year        runtime      seasons     imdb_score  \
# count  1.243470e+05  124347.000000  124347.000000  8153.000000  118296.000000
# mean   4.062528e+05    1996.233234      95.536973     2.337790       5.967783
# std    5.614483e+05      27.807050      30.166352     3.130184       1.241557
# min    1.000000e+00    1912.000000       1.000000     1.000000       1.100000
# 25%    3.899600e+04    1983.000000      83.000000     1.000000       5.200000
# 50%    1.339340e+05    2009.000000      93.000000     1.000000       6.100000
# 75%    5.711600e+05    2017.000000     109.000000     2.000000       6.800000
# max    2.371153e+06    2022.000000     540.000000    49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score
# count  1.182720e+05    124332.000000  114082.000000
# mean   2.324281e+04        10.165321       5.992100
# std    8.840151e+04        40.739203       1.321033
# min    5.000000e+00         0.000011       0.800000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The merged dataset consists of 19 columns that provide information about movie/show metadata and cast/crew details. Below is a description of each variable:
#
# **1. Identification Variables**
#
# * **Column Name:** Id
# * **Description:** Unique Identifier for a movie or TV show
# * **Data Type:** String
#
#
# * **Column Name:** person_id
# * **Description:** Unique identifier for a cast or crew member
# * **Data Type:** Integer
#
#
#
# **2. Cast & Crew Details**
#
# * **Column Name:** name
# * **Description:** Name of the cast or crew member
# * **Data Type:** String
#
#
# * **Column Name:** character
# * **Description:** Name of the character played (for actors)
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** role
# * **Description:** Role of the person in the production (e.g., ACTOR, DIRECTOR, WRITER)
# * **Data Type:** String
#
#
#
# **3. Movie/Show Metadata**
#
# * **Column Name:** title
# * **Description:** Name of the movie or TV show
# * **Data Type:** String
#
#
# * **Column Name:** type
# * **Description:** Type of content (MOVIE or SHOW)
# * **Data Type:** String
#
#
# * **Column Name:** description
# * **Description:** Brief synopsis of the title
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** release_year
# * **Description:** Year the movie or show was released
# * **Data Type:** Integer
#
#
# * **Column Name:** age_certification
# * **Description:** Age rating (e.g., PG, R, TV-MA)
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** runtime
# * **Description:** Duration in minutes
# * **Data Type:** Integer
#
#
# * **Column Name:** genres
# * **Description:** List of genres (e.g., Action, Comedy, Drama)
# * **Data Type:** String (stored as list format)
#
#
# * **Column Name:** production_countries
# * **Description:** Countries where the movie/show was produced (stored as a list)
# * **Data Type:** String
#
#
#
# **4. TV Show-Specific Variable**
#
# * Column Name Description Data Type
#
# Based on the images provided, here is the extracted text describing the dataset variables and metadata.
#
# **The merged dataset consists of 19 columns that provide information about movie/show metadata and cast/crew details. Below is a description of each variable:**
#
# **1. Identification Variables**
#
# * **Column Name:** Id
# * **Description:** Unique Identifier for a movie or TV show
# * **Data Type:** String
#
#
# * **Column Name:** person_id
# * **Description:** Unique identifier for a cast or crew member
# * **Data Type:** Integer
#
#
#
# **2. Cast & Crew Details**
#
# * **Column Name:** name
# * **Description:** Name of the cast or crew member
# * **Data Type:** String
#
#
# * **Column Name:** character
# * **Description:** Name of the character played (for actors)
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** role
# * **Description:** Role of the person in the production (e.g., ACTOR, DIRECTOR, WRITER)
# * **Data Type:** String
#
#
#
# **3. Movie/Show Metadata**
#
# * **Column Name:** title
# * **Description:** Name of the movie or TV show
# * **Data Type:** String
#
#
# * **Column Name:** type
# * **Description:** Type of content (MOVIE or SHOW)
# * **Data Type:** String
#
#
# * **Column Name:** description
# * **Description:** Brief synopsis of the title
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** release_year
# * **Description:** Year the movie or show was released
# * **Data Type:** Integer
#
#
# * **Column Name:** age_certification
# * **Description:** Age rating (e.g., PG, R, TV-MA)
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** runtime
# * **Description:** Duration in minutes
# * **Data Type:** Integer
#
#
# * **Column Name:** genres
# * **Description:** List of genres (e.g., Action, Comedy, Drama)
# * **Data Type:** String (stored as list format)
#
#
# * **Column Name:** production_countries
# * **Description:** Countries where the movie/show was produced (stored as a list)
# * **Data Type:** String
#
#
#
# **4. TV Show-Specific Variable**
#
# * **Column Name:** seasons
# * **Description:** Number of seasons (only for TV shows, missing for movies)
# * **Data Type:** Integer (Can be Null)
#
#
#
# **5. Performance Metrics**
#
# * **Column Name:** imdb_id
# * **Description:** IMDb identifier for the title
# * **Data Type:** String (Can be Null)
#
#
# * **Column Name:** imdb_score
# * **Description:** IMDb rating (scale of 1-10)
# * **Data Type:** Float (Can be Null)
#
#
# * **Column Name:** imdb_votes
# * **Description:** Number of votes received on IMDb
# * **Data Type:** Integer (Can be Null)
#
#
# * **Column Name:** tmdb_popularity
# * **Description:** Popularity score from TMDb (higher means more popular)
# * **Data Type:** Float
#
#
# * **Column Name:** tmdb_score
# * **Description:** TMDb rating (scale of 1-10)
# * **Data Type:** Float (Can be Null)
#
#
#
# **Observations & Notes**
#
# * **Null/Missing Values:** Columns like character, age_certification, seasons, imdb_score, and tmdb_score have missing values.
# * **Genres & Production Countries:** Stored as lists, may require processing for better analysis.
# * **IMDb & TMDb Scores:** Useful for evaluating a title's popularity and quality.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
merged_df.nunique()
# Out:
# person_id               80508
# id                       8861
# name                    79758
# character               71097
# role                        2
# title                    8748
# type                        2
# description              8833
# release_year              110
# age_certification          11
# runtime                   204
# genres                   1965
# production_countries      482
# seasons                    30
# imdb_id                  8267
# imdb_score                 85
# imdb_votes               3623
# tmdb_popularity          5267
# tmdb_score                 88
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
import ast

# Remove Duplicate Rows
merged_df=merged_df.drop_duplicates()

# Handle missing ratings

# Fill missing 'character' with 'Unknown' (for actors)
merged_df['character']=merged_df['character'].fillna('Unknown')

# Fill missing 'description' with 'No description available'
merged_df['description']=merged_df['description'].fillna('No description available')

# Fill missing 'age_certification' with 'Unrated'
merged_df['age_certification']=merged_df['age_certification'].fillna('Unrated')


# Fill missing numerical value with appropriate substitutes
merged_df['seasons']=merged_df['seasons'].fillna(0)
merged_df['imdb_votes']=merged_df['imdb_votes'].fillna(0)
merged_df['tmdb_popularity']=merged_df['tmdb_popularity'].fillna(0)

# Convert production countries to lists if they are in string format
merged_df['genres_list'] = merged_df['genres'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

merged_df['countries_list'] = merged_df['production_countries'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# Convert Data Types

merged_df['seasons']=merged_df['seasons'].astype(int)

# %%
merged_df.drop('imdb_id' , axis=1,inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# person_id                   0
# id                          0
# name                        0
# character                   0
# role                        0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_score               6051
# imdb_votes                  0
# tmdb_popularity             0
# tmdb_score              10169
# genres_list                 0
# countries_list              0
# dtype: int64

# %%
# Check how to fill Null values in columns 'imdb_score' and 'tmdb_score'

sns.boxplot(x=merged_df['tmdb_score'])
plt.title('Boxplot of IMDb Scores')
plt.show()

# %%
sns.kdeplot(merged_df['tmdb_score'], fill=True)
plt.title('KDE Plot of IMDb Scores')
plt.show()

# %%
# Check how to fill Null values in columns 'imdb_score' and 'tmdb_score'

sns.boxplot(x=merged_df['imdb_score'])
plt.title('Boxplot of IMDb Scores')
plt.show()

# %%
sns.kdeplot(merged_df['imdb_score'], fill=True)
plt.title('KDE Plot of IMDb Scores')
plt.show()

# %%
# Fill missing numerical value with appropriate substitutes
merged_df['imdb_score']=merged_df['imdb_score'].fillna(titles_df['imdb_score'].median())
merged_df['tmdb_score']=merged_df['tmdb_score'].fillna(titles_df['tmdb_score'].median())

# %%
merged_df.isnull().sum()
# Out:
# person_id               0
# id                      0
# name                    0
# character               0
# role                    0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# genres_list             0
# countries_list          0
# dtype: int64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124179 non-null  int64
#  1   id                    124179 non-null  object
#  2   name                  124179 non-null  object
#  3   character             124179 non-null  object
#  4   role                  124179 non-null  object
#  5   title                 124179 non-null  object
#  6   type                  124179 non-null  object
#  7   description           124179 non-null  object
#  8   release_year          124179 non-null  int64
#  9   age_certification     124179 non-null  object
#  10  runtime               124179 non-null  int64
#  11  genres                124179 non-null  object
#  12  production_countries  124179 non-null  object
#  13  seasons               124179 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
# Here is what was done:-
#
# Removed 168 duplicate rows reducing the datasset rows 124179.
#
# Handled missing values: Filled character with 'Unknown' for actors. Replaced missing description with 'No description available".
#
# Set age_certification as 'Unrated' for missing values
#
# set seasons to 0 for movies.
#
# Filled missing imdb_score and tmdb_score with their median values. Set missing imdb_votes tmdb_popularitiy to 0.
#
# converted genres and production_countries to list format for better analysis .
#
# Standardized data types (eg. release_year , runtime , imdb_votes as integers)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124179 non-null  int64
#  1   id                    124179 non-null  object
#  2   name                  124179 non-null  object
#  3   character             124179 non-null  object
#  4   role                  124179 non-null  object
#  5   title                 124179 non-null  object
#  6   type                  124179 non-null  object
#  7   description           124179 non-null  object
#  8   release_year          124179 non-null  int64
#  9   age_certification     124179 non-null  object
#  10  runtime               124179 non-null  int64
#  11  genres                124179 non-null  object
#  12  production_countries  124179 non-null  object
#  13  seasons               124179 non-null  int64
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# #### Chart - 1 Distribution of Show Types (Movie vs TV)

# %%
from matplotlib import figure
# Chart - 1 visualization code
plt.figure(figsize=(5,5))
sns.countplot(data=merged_df, x='type')
plt.title('Distribution of Movies vs. Shows')
plt.xlabel('Type')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The countplot helps understand whether the dataset is dominated by movies or TV showes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# There are more movies than TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive:If the platform wants to invest in content, focusing on movies may cater large audience.
#
# Negative: Underinvestment in TV shows could lead to losing long term subscribers who prefer series over movies.

# %% [markdown]
# #### Chart - 2 Top 15 genres

# %%
from collections import Counter
# Chart - 2 visualization code

all_genres=[genre for sublist in merged_df['genres_list'] for genre in sublist]
genre_counts=Counter(all_genres).most_common(15)
genres, counts=zip(*genre_counts)

plt.figure(figsize=(15,6))
sns.barplot(x=list(genres), y=list(counts), palette='rocket', width=0.5)
plt.xticks(rotation=40)
plt.title('Top 15 common genre')
plt.xlabel('Genre Name')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The barplot identifies audience preferences based on most frequent genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# As we can see most dominant genres is Drama, comedy thriller.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive: Streaming services can prioritize these genres for production and licencing deals.
#
# Negative: Over-saturation of these genres could limit diversity , making niche audience feel neglected.

# %% [markdown]
# #### Chart - 3  Release Year Distribution

# %%
# Chart - 3 visualization code

plt.figure(figsize=(13,5))
sns.histplot(merged_df['release_year'], bins=30, kde=30, color='blue')
plt.title('Movies and Seriers relased over the year')
plt.xlabel('Release Year')
plt.ylabel('Count')
new_ticks = range(1920, 2030, 5)
plt.xticks(new_ticks)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# This histplots can shows how content production has evolved over the year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# ---A  surge in releases during the 2010s  but a decline after 2020s . Probaly due to Covid-19 Pendamic.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive: Idenntifies golden periods for content creation and industry growth.
#
# Negative: The decline post 2020 could indicate potential market saturation or impact of streaming platforms competition.

# %% [markdown]
# #### Chart - 4 IMDB  Rating Distribution

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,5))
sns.histplot(merged_df['imdb_score'], bins=20 , kde=True)
plt.title('Distribution of IMBD Scores')
plt.xlabel('IMBD Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# This histplot showing the quality perception of the content.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Most content has IMDB rating between 4-8

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive:High engagement expected for well-rated content , driving better recommendations
#
# Negative: A Large volumne of mid rated content could indicate a lack of exception titile that drive strong engagement.

# %% [markdown]
# #### Chart - 5 TMDb Popularity Distribution

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,5))
sns.histplot(merged_df['tmdb_score'], bins=20 , kde=True, color='green')
plt.title('Distribution of TMDB Scores')
plt.xlabel('TMDB Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The histplot of the distribution of TMDB scores is similar to IMDB scores but focused on audience-driven ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Scores mostly range lies between 5-8, similar to IMDB , confirming consistancy

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive: Consistent ratings across platforms indicate reliable
# audience feedback.
#
# Negative: If most content is rated similarly , It might indicate a lack of differentiation in quality.

# %% [markdown]
# #### Chart - 6 Rutime distribution

# %%
# Chart - 6 visualization code
plt.figure(figsize=(15,6))
sns.boxplot(x=merged_df['runtime'])
plt.xticks(range(0,500,20))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# In this boxplot we can detect outliers and spread

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Most content ranges between 80 -120

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# Optimized runtime improves viewer completion rates.
#
# Negative growth insight:
# Limited experimentation with short-form or long-form formats.

# %% [markdown]
# #### Chart - 7 Age Certification Count

# %%
# Chart - 7 visualization code
plt.figure(figsize=(8,5))
sns.barplot(data=merged_df['age_certification'].value_counts())
plt.title('Age certification Distribution')
plt.xlabel('Age Certification')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Barplot helps to know categorical data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Heavy focuses on Adult content

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Impact: Strong adult and above age 13  retention
#
# Negative: Weak family/kids positioning

# %% [markdown]
# #### Chart - 8 Seasons Distribution (TV Shows)

# %%
# Chart - 8 visualization code

plt.figure(figsize=(10,6))
sns.countplot(data=merged_df[merged_df['type']=='SHOW'], x='seasons')
plt.title('Season count for TV shows')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To visualize the distribution and frequency of occurrences of TV Showes category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Monst of the TV showes has only one 1 seasons

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Impact: Low long term IP TV shows Distribution
#
# Negative: Fewer franchaise lavel shows means lower big shows

# %% [markdown]
# ##**BIVARIATE ANALYSIS**

# %% [markdown]
# #### Chart - 9 - IMDB rating by Show Type

# %%
# Chart - 9 visualization code
plt.figure(figsize=(8,6))
sns.boxenplot(data=merged_df, x='type', y = 'imdb_score')
plt.title('IMDB rating by show type')
plt.yticks(range(0,10,1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Boxplots compare numeric distributors across categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# TV shows generally has higher IMDB rating than movies

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# TV content offers stronger quality-driven retention.
#
# Negative growth insight:
# Movie quality inconsistency may affect negative growth.

# %% [markdown]
# #### Chart - 10 IMDB score vs TMDB score

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,6))
sns.scatterplot(data=merged_df, x='imdb_score', y='tmdb_score')
plt.title('IMDB vs TMDB score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Scatter plots reveal correlation between two numerical variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Strong Correlation between IMDB and TMDB score

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# Ratings credibility is consistent across platforms.
#
# Negative growth insight:
# Outliers suggest possible rating manipulation or niche appeal.

# %% [markdown]
# #### Chart - 11 IMDB votes vs TMDB popularity

# %%
# Chart - 11 visualization
plt.figure(figsize=(8,6))
sns.scatterplot(data=merged_df, x='imdb_votes', y='tmdb_popularity')
plt.xscale('log')
plt.title('IMDB votes vs TMDB popularity')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Shows scale effects and engagement patterns

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Higher votes count strongly increase popularity

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# Marketing that boosts voting improves discoverability.
#
# Negative growth insight:
# New content struggles without early traction.

# %% [markdown]
# #### Chart - 12 Genre vs IMDB Rating

# %%
# Chart - 12 visualization code


#  explode the clean lists
genre_df = merged_df.explode('genres_list').reset_index(drop=True)

# Calculate top genres
top_genres = genre_df['genres_list'].value_counts().index
print(top_genres)
#  Filter and Plot
filtered_genres = genre_df[genre_df['genres_list'].isin(top_genres)]

plt.figure(figsize=(18, 7))
# 'order=top_genres' ensures the bars are sorted from highest to lowest
sns.boxplot(data=filtered_genres, x='genres_list', y='imdb_score' ,order=top_genres)
plt.title('IMDB Score Distribution by Top 10 Genres')
plt.xticks(rotation=45)
plt.yticks(range(1,11))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Index(['drama', 'comedy', 'thriller', 'action', 'romance', 'crime', 'horror',
#        'european', 'scifi', 'fantasy', 'family', 'western', 'history',
#        'documentation', 'music', 'war', 'animation', 'sport', 'reality'],
#       dtype='object', name='genres_list')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To Compare imdb_score across genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Drama and Documantry genres score are highest.
#
# Documentation and History have the highest and Horror has the lowest median scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive:
#
# Investing in Documentaries is the safest route for a platform aiming for "High Quality" branding.
#
# Negative:
# - Saturation: High volumes of poorly-rated Drama and Comedy titles may dilute marketing efforts.

# %% [markdown]
# #### Chart - 13 Production movies series across country

# %%
# Chart - 13 visualization code

country_df=merged_df.explode('countries_list')
countries_df=country_df['countries_list'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(data=countries_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To identfies regional dominance

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# US dominance over all the countries in content production

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive: It will increase global audiance reach
#
# Negative: Less invesment in regional or local markets

# %% [markdown]
# # **MULTIVARIATE ANALYSIS**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

heatmap_data=pd.crosstab(genre_df['genres_list'],genre_df['type'])
plt.figure(figsize=(10,6))
sns.heatmap(data=heatmap_data, cmap='coolwarm')
plt.title('Genre vs Show Type Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Heatmaps show relationships across two categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Drama dominates both Movies and TV formats.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
# Genre scalability across formats.
#
# Negative growth insight:
# Lack of genre diversification.

# %% [markdown]
# #### Chart - 15 - Country × Show Type

# %%
# Pair Plot visualization code

top_countries = country_df["countries_list"].value_counts().head(5).index
filtered_countries = country_df[country_df["countries_list"].isin(top_countries)]

sns.countplot(data=filtered_countries, x="countries_list", hue="type")
plt.title("Country vs Show Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Compares two categorical dimensions simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
#
# US leads in both Movies and TV.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
# Strong, stable production pipeline.
#
# Negative growth insight:
# Limited international TV expansion.

# %% [markdown]
# # Chart - 16 Genre × IMDb × Popularity

# %%
# Chart - 16 visualization code
plt.figure(figsize=(10,8))
sns.scatterplot(
    data=filtered_genres,
    x="imdb_score",
    y="tmdb_popularity",
    hue="genres_list"
)
plt.title("Genre Impact on Ratings & Popularity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Multivariate scatter plots show interaction effects.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# High-rated Drama titles drive popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# Quality-driven marketing strategy.
#
# Negative growth insight:
# Comedy popularity inconsistent.

# %% [markdown]
# # Chart - 17 visualization code

# %%
# Chart - 17 visualization code
tv_df = merged_df[merged_df["type"] == "SHOW"]

sns.scatterplot(
    data=tv_df,
    x="seasons",
    y="imdb_score",
    size="tmdb_popularity"
)
plt.title("TV Seasons vs Rating & Popularity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Evaluates impact of multiple numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# More seasons do not guarantee better ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Positive business impact:
# Optimizes renewal decisions.
#
# Negative growth insight:
# Risk of overextending weak shows.

# %% [markdown]
# # Chart - 18 Actor Participation Volume

# %%
# Chart - 18 visualization code
merged_df["name"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Most Featured Actors")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Identifies dependency patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
#
# Repeated casting of specific actors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
#
# Positive business impact:
# Familiar faces improve recall.
#
# Negative growth insight:
# Casting fatigue risk.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# Based on the exploratory data analysis of the merged titles and credits datasets, Amazon Prime Video should adopt a quality-focused, regionally diversified, and retention-driven content strategy.
#
# Key Recommendations:
#
# --Shift from Volume to Quality
#
# While movies dominate the catalog, TV shows consistently receive higher IMDb ratings.
#
# Amazon should invest in fewer but higher-quality productions, especially in high-performing genres like Drama and Documentary.
#
# --Strengthen Long-Running TV Franchises
#
# Most TV shows have only 1–2 seasons, limiting long-term subscriber retention.
#
# Developing multi-season flagship series will improve user stickiness and lifetime value.
#
# --Leverage Ratings & Popularity for Marketing
#
# IMDb ratings strongly correlate with TMDb popularity.
#
# Amazon should promote high-rated titles more aggressively to maximize visibility and engagement.
#
# --Reduce Genre Saturation
#
# Over-reliance on Drama, Comedy, and Action risks content fatigue.
#
# Introducing diverse and experimental genres can attract niche audiences and reduce churn.
#
# --Expand Regional & Local Content
#
# Content production is heavily US-centric.
#
# Investing in region-specific originals (India, Europe, LATAM) will improve global reach and local engagement.
#
# --Optimize Casting Strategy
#
# Repeated actor usage improves recall but may cause fatigue.
#
# Balance familiar faces with new talent discovery to maintain freshness.
#
# 👉 Overall Strategy:
# Amazon Prime Video should move toward a data-driven content investment model, prioritizing high-quality, high-retention content over sheer catalog size.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# This Exploratory Data Analysis (EDA) of the Amazon Prime Video dataset provided valuable insights into content composition, quality, popularity, and production trends.
#
# By merging the titles and credits datasets, we were able to analyze not only what content exists, but also who contributes to it and how audiences respond. The analysis revealed that while Amazon Prime has aggressively expanded its content library—especially movies—the true drivers of user engagement and ratings are high-quality TV shows, strong genres like Drama, and strategically marketed titles.
#
# The project successfully demonstrated how:
#
# Univariate analysis explained content distribution,
#
# Bivariate analysis uncovered relationships between ratings, popularity, and categories,
#
# Multivariate analysis revealed deeper interactions influencing business outcomes.
#
# These insights can directly support content strategy planning, marketing decisions, and investment prioritization.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
